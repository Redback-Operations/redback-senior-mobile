# %% [markdown]
# # Merging Cost and PPH Datasets

# %%
# importing the required libraries
import pandas as pd

# Loading the preprocessed cost and pph dataset files 
cost_df =  pd.read_csv('../Data/preprocessed-data/headlthcare_costs_summary_by_state_2022_23.csv')
pph_df = pd.read_csv('../Data/preprocessed-data/pph_ppn_level_2022_23.csv')

# %%
# Creating a state mapping for identical states on both the data frames

state_map = {
    'NSW': 'NSW', 'VIC': 'VIC', 'QLD': 'QLD', 'SA': 'SA', 
    'WA': 'WA', 'TAS': 'TAS', 'NT': 'NT', 'ACT': 'ACT',
    'Qld': 'QLD', 'Vic': 'VIC', 'Tas': 'TAS'
}

cost_df['State'] = cost_df['State'].map(state_map)
pph_df['State'] = pph_df['State'].map(state_map)

# %%
# Checking for missing state values

print("Missing states in cost:", cost_df['State'].isna().sum())
print("Missing states in PPH:", pph_df['State'].isna().sum())

# Unique states
print("Cost DF States:", sorted(cost_df['State'].unique()))
print("PPH DF States:", sorted(pph_df['State'].unique()))
# Out:
# Missing states in cost: 0
# Missing states in PPH: 0
# Cost DF States: ['ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA']
# PPH DF States: ['ACT', 'NSW', 'NT', 'QLD', 'SA', 'TAS', 'VIC', 'WA']

# %%
# Merging two datasets
merged_cost_pph_df = pph_df.merge(cost_df, on='State', how='left')

# %%
# Checking for missing cost data after merging
print("Missing cost values:", merged_cost_pph_df['Cost_per_person'].isna().sum())

# Ensure each state in the merged dataset has only one unique cost value
state_cost_check = merged_cost_pph_df.groupby('State')['Cost_per_person'].nunique()
print(state_cost_check)

# Previewing the merge datasets
merged_cost_pph_df.head(30)
# Out:
# Missing cost values: 0
# State
# ACT    1
# NSW    1
# NT     1
# QLD    1
# SA     1
# TAS    1
# VIC    1
# WA     1
# Name: Cost_per_person, dtype: int64
#    PHN_Code                                      PHN_Name State  \
# 0    PHN101                    Central and Eastern Sydney   NSW
# 1    PHN102                               Northern Sydney   NSW
# 2    PHN103                                Western Sydney   NSW
# 3    PHN104                         Nepean Blue Mountains   NSW
# 4    PHN105                          South Western Sydney   NSW
# 5    PHN106                             South Eastern NSW   NSW
# 6    PHN107                                   Western NSW   NSW
# 7    PHN108          Hunter New England and Central Coast   NSW
# 8    PHN109                                   North Coast   NSW
# 9    PHN110                                  Murrumbidgee   NSW
# 10   PHN201                       North Western Melbourne   VIC
# 11   PHN202                             Eastern Melbourne   VIC
# 12   PHN203                       South Eastern Melbourne   VIC
# 13   PHN204                                     Gippsland   VIC
# 14   PHN206                              Western Victoria   VIC
# 15   PHN301                                Brisbane North   QLD
# 16   PHN302                                Brisbane South   QLD
# 17   PHN303                                    Gold Coast   QLD
# 18   PHN304                Darling Downs and West Moreton   QLD
# 19   PHN305                            Western Queensland   QLD
# 20   PHN306  Central Queensland, Wide Bay, Sunshine Coast   QLD
# 21   PHN307                           Northern Queensland   QLD
# 22   PHN401                                      Adelaide    SA
# 23   PHN402                                    Country SA    SA
# 24   PHN501                                   Perth North    WA
# 25   PHN502                                   Perth South    WA
# 26   PHN503                                    Country WA    WA
# 27   PHN601                                      Tasmania   TAS
# 28   PHN701                            Northern Territory    NT
# 29   PHN801                  Australian Capital Territory   ACT
#
#     PPH_rate_per_100k  Cost_per_person
# 0            1688.577          111.426
# 1            1795.760          111.426
# 2            1616.840          111.426
# 3            1695.080          111.426
# 4            1639.889          111.426
# 5            1651.692          111.426
# 6            1833.080          111.426
# 7            1701.037          111.426
# 8            1775.222          111.426
# 9            2161.560          111.426
# 10           1924.654          119.902
# 11           1814.577          119.902
# 12           1929.852          119.902
# 13           2171.280          119.902
# 14           1909.154          119.902
# 15           2314.538          124.859
# 16           2207.148          124.859
# 17           2230.000          124.859
# 18           2431.615          124.859
# 19           3290.250          124.859
# 20           2187.852          124.859
# 21           2450.630          124.859
# 22           1872.269          120.242
# 23           1826.760          120.242
# 24           1749.538          120.652
# 25           1722.962          120.652
# 26           2103.692          120.652
# 27           1921.077          125.173
# 28           4152.960          158.075
# 29           1703.880          146.791

# %%
# Saving the merged dataframe into dataset file
merged_cost_pph_df.to_csv('../Data/preprocessed-data/merged_cost_pph.csv', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
